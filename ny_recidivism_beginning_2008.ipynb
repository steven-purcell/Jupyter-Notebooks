# %%
import pandas as pd
import pandas_profiling
import numpy as np

# %%
full_data = pd.read_csv('C:\\Users\\steve\\OneDrive\\Documents\\Datasets\\recidivism\\Recidivism__Beginning_2008.csv')
reoffender_data=full_data[full_data['Return Status']!= 'Not Returned']
non_reoffender_data=full_data[full_data['Return Status']== 'Not Returned']
# print(full_data.sample())
# print(reoffender_data.sample())

# %%
pandas_profiling.ProfileReport(full_data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
# %matplotlib inline
# age_ticks = range(18, 80, 2)
reoffender_age = reoffender_data['Age at Release']
non_age = non_reoffender_data['Age at Release']
plt.hist([reoffender_age,non_age], label=['reoffender','non_reoffender'], bins=20)
# plt.xticks(age_ticks)
plt.xlabel('Age at Release')
plt.ylabel('Count')
plt.legend(loc='upper right')
plt.show()
